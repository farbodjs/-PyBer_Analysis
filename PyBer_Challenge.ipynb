# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
sum_rides_by_type = pyber_data_df.groupby(["type"]).count()["ride_id"]
sum_rides_by_type
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
sum_drivers_by_type = city_data_df.groupby(["type"]).sum()["driver_count"]
sum_drivers_by_type
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
sum_fare_by_type = pyber_data_df.groupby(["type"]).sum()["fare"]
sum_fare_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avg_fares_by_type = sum_fare_by_type / sum_rides_by_type
avg_fares_by_type
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avg_fares_by_driver = sum_fare_by_type / sum_drivers_by_type
avg_fares_by_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.DataFrame ({
    "Total Rides": sum_rides_by_type,
    "Total Drivers": sum_drivers_by_type,
    "Total Fare": sum_fare_by_type,
    "Average Fare By Ride": avg_fares_by_type,
    "Average Fare Per Driver": avg_fares_by_driver})
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fare  Average Fare By Ride  \
# type
# Rural             125             78     4327.93             34.623440
# Suburban          625            490    19356.33             30.970128
# Urban            1625           2405    39854.38             24.525772
#
#           Average Fare Per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fare  Average Fare By Ride  \
# Rural             125             78     4327.93             34.623440
# Suburban          625            490    19356.33             30.970128
# Urban            1625           2405    39854.38             24.525772
#
#           Average Fare Per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
pyber_summary_df.dtypes
# Out:
# Total Rides                  int64
# Total Drivers                int64
# Total Fare                 float64
# Average Fare By Ride       float64
# Average Fare Per Driver    float64
# dtype: object

# %%
#  8. Format the columns.
pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,}".format)
pyber_summary_df["Total Fare"] = pyber_summary_df["Total Fare"].map("${:,.2f}".format)
pyber_summary_df["Average Fare By Ride"] = pyber_summary_df["Average Fare By Ride"].map("${:,.2f}".format)
pyber_summary_df["Average Fare Per Driver"] = pyber_summary_df["Average Fare Per Driver"].map("${:,.2f}".format)
pyber_summary_df
# Out:
#          Total Rides Total Drivers  Total Fare Average Fare By Ride  \
# Rural            125            78   $4,327.93               $34.62
# Suburban         625           490  $19,356.33               $30.97
# Urban          1,625         2,405  $39,854.38               $24.53
#
#          Average Fare Per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df = pyber_data_df.rename(columns =
                                     {"city": "City",
                                     "date": "Date", 
                                     "fare": "Fare", 
                                     "ride_id": "Ride Id",
                                     "driver_count": "No. Drivers",
                                     "type": "City Type"})
pyber_data_df
# Out:
#                     City                 Date   Fare        Ride Id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       No. Drivers City Type
# 0               5     Urban
# 1              72     Urban
# 2              57     Urban
# 3              34     Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
sum_fare_by_date = pyber_data_df.groupby(["Date"]).sum()["Fare"]
sum_fare_by_date
# Out:
# Date
# 2019-01-01 00:08:16    37.91
# 2019-01-01 00:46:46    47.74
# 2019-01-01 02:07:24    24.07
# 2019-01-01 03:46:50     7.57
# 2019-01-01 05:23:21    10.75
#                        ...
# 2019-05-08 04:20:00    21.99
# 2019-05-08 04:39:49    18.45
# 2019-05-08 07:29:01    18.55
# 2019-05-08 11:38:35    19.77
# 2019-05-08 13:10:18    18.04
# Name: Fare, Length: 2375, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
pyber_data_df = pyber_data_df.reset_index()
# Set index of 'Date'
pyber_data_df.set_index("Date", inplace = True)
pyber_data_df.head(10)
# Out:
#                      index                City   Fare        Ride Id  \
# Date
# 2019-01-14 10:14:22      0  Lake Jonathanshire  13.83  5739410935873
# 2019-03-04 18:24:09      1  South Michelleport  30.24  2343912425577
# 2019-02-24 04:29:00      2  Port Samanthamouth  33.44  2005065760003
# 2019-02-10 23:22:03      3          Rodneyfort  23.44  5149245426178
# 2019-03-06 04:28:35      4          South Jack  34.58  3908451377344
# 2019-03-11 12:26:48      5        South Latoya   9.52  1994999424437
# 2019-02-27 11:17:56      6       New Paulville  43.25   793208410091
# 2019-04-26 00:43:24      7        Simpsonburgh  35.98   111953927754
# 2019-01-08 03:28:48      8     South Karenland  35.09  7995623208694
# 2019-03-09 06:26:29      9       North Jasmine  42.81  5327642267789
#
#                      No. Drivers City Type
# Date
# 2019-01-14 10:14:22            5     Urban
# 2019-03-04 18:24:09           72     Urban
# 2019-02-24 04:29:00           57     Urban
# ...

# %%
# Create new df for fares data
fares_by_date = pyber_data_df[['City Type', 'Fare']]
# Set index as datetime 
fares_by_date.index = pd.to_datetime(fares_by_date.index)
fares_by_date.head(10)
# Out:
#                     City Type   Fare
# Date
# 2019-01-14 10:14:22     Urban  13.83
# 2019-03-04 18:24:09     Urban  30.24
# 2019-02-24 04:29:00     Urban  33.44
# 2019-02-10 23:22:03     Urban  23.44
# 2019-03-06 04:28:35     Urban  34.58
# 2019-03-11 12:26:48     Urban   9.52
# 2019-02-27 11:17:56     Urban  43.25
# 2019-04-26 00:43:24     Urban  35.98
# 2019-01-08 03:28:48     Urban  35.09
# 2019-03-09 06:26:29     Urban  42.81

# %%
# Calculate the sum of fares by city type and date
total_fares_by_date = fares_by_date.groupby(['City Type', 'Date']).sum()
# reset the index
total_fares_by_date.reset_index()
# Out:
#      City Type                Date   Fare
# 0        Rural 2019-01-01 09:45:36  43.69
# 1        Rural 2019-01-02 11:18:32  52.12
# 2        Rural 2019-01-03 19:51:01  19.90
# 3        Rural 2019-01-04 03:31:26  24.88
# 4        Rural 2019-01-06 07:38:40  47.33
# ...        ...                 ...    ...
# 2370     Urban 2019-05-08 04:20:00  21.99
# 2371     Urban 2019-05-08 04:39:49  18.45
# 2372     Urban 2019-05-08 07:29:01  18.55
# 2373     Urban 2019-05-08 11:38:35  19.77
# 2374     Urban 2019-05-08 13:10:18  18.04
#
# [2375 rows x 3 columns]

# %%
# 4. # Create a pivot table DataFrame
fares_pivot_table = pd.pivot_table(total_fares_by_date, index=['Date'],
                                  columns=['City Type'])
fares_pivot_table
# Out:
#                      Fare
# City Type           Rural Suburban  Urban
# Date
# 2019-01-01 00:08:16   NaN      NaN  37.91
# 2019-01-01 00:46:46   NaN    47.74    NaN
# 2019-01-01 02:07:24   NaN    24.07    NaN
# 2019-01-01 03:46:50   NaN      NaN   7.57
# 2019-01-01 05:23:21   NaN      NaN  10.75
# ...                   ...      ...    ...
# 2019-05-08 04:20:00   NaN      NaN  21.99
# 2019-05-08 04:39:49   NaN      NaN  18.45
# 2019-05-08 07:29:01   NaN      NaN  18.55
# 2019-05-08 11:38:35   NaN      NaN  19.77
# 2019-05-08 13:10:18   NaN      NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

filtered_fares_by_date = fares_pivot_table.loc['2019-01-01':'2019-04-29']
filtered_fares_by_date
# Out:
#                      Fare
# City Type           Rural Suburban  Urban
# Date
# 2019-01-01 00:08:16   NaN      NaN  37.91
# 2019-01-01 00:46:46   NaN    47.74    NaN
# 2019-01-01 02:07:24   NaN    24.07    NaN
# 2019-01-01 03:46:50   NaN      NaN   7.57
# 2019-01-01 05:23:21   NaN      NaN  10.75
# ...                   ...      ...    ...
# 2019-04-29 20:54:19   NaN      NaN  28.41
# 2019-04-29 21:20:41   NaN      NaN  13.59
# 2019-04-29 22:08:22   NaN    25.75    NaN
# 2019-04-29 23:05:04   NaN      NaN  14.59
# 2019-04-29 23:10:18   NaN    29.39    NaN
#
# [2218 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# 7. Check that the datatype for the index is datetime using df.info()
# df.index = pd.to_datetime(df.index)
filtered_fares_by_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2218 entries, 2019-01-01 00:08:16 to 2019-04-29 23:10:18
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Fare, Rural)     116 non-null    float64
#  1   (Fare, Suburban)  579 non-null    float64
#  2   (Fare, Urban)     1523 non-null   float64
# dtypes: float64(3)
# memory usage: 69.3 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
weekly_fares_by_date = filtered_fares_by_date.resample('W').sum()
weekly_fares_by_date
# Out:
#               Fare
# City Type    Rural Suburban    Urban
# Date
# 2019-01-06  187.92   721.60  1661.68
# 2019-01-13   67.65  1105.13  2050.43
# 2019-01-20  306.00  1218.20  1939.02
# 2019-01-27  179.69  1203.28  2129.51
# 2019-02-03  333.08  1042.79  2086.94
# 2019-02-10  115.80   974.34  2162.64
# 2019-02-17   95.82  1045.50  2235.07
# 2019-02-24  419.06  1412.74  2466.29
# 2019-03-03  175.14   858.46  2218.20
# 2019-03-10  303.94   925.27  2470.93
# 2019-03-17  163.39   906.20  2044.42
# 2019-03-24  189.76  1122.20  2368.37
# 2019-03-31  199.42  1045.06  1942.77
# 2019-04-07  501.24  1010.73  2356.70
# 2019-04-14  269.79   784.82  2390.72
# 2019-04-21  214.14  1149.27  2303.80
# 2019-04-28  191.85  1357.75  2238.29
# 2019-05-05   67.60   167.92   342.63

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
# initialize the plot
weekly_fares_by_date.plot(kind='line', figsize=(20,6))

# Add title and axis-labels
plt.title("Total Fare by City Type", fontsize=20)
plt.ylabel("Fare ($USD)", fontsize=16)
plt.xlabel("Month", fontsize=16)

# Create a legend
lgnd = plt.legend(fontsize="12", mode="Expanded",
         scatterpoints=1, loc="center", title="City Type")
lgnd.get_title().set_fontsize(12)

# Save the figure
plt.tight_layout()
plt.savefig('analysis/challenge_figure.png')

plt.show()
